# %%
from train import MedSAMTrainer

# The parameters below reproduce those used in the lwnet paper
params = {
    "experiment_name": "medsam_vessmap_4_samples",
    "run_name": "full_finetune_wd_0_lr_0001",
    "validate_every": 20,
    #"save_val_imgs": "",
    #"val_img_indices": "0 1 2 3",
    "dataset_path": "/home/chcomin/Dropbox/shared_datasets/VessMAP",
    "dataset_class": "vessmap_color_bce",
    "dataset_params": "split_folder=splits_4_samples",
    "split_strategy": "file_train_val",
    "resize_size": "1024 1024",
    #'ignore_class_weights': '',
    "loss_function": "bce",
    "model_class": "medsam",
    "model_params": "freeze_encoder=False",
    "num_epochs": 100,
    "validation_metric": "Dice",
    "maximize_validation_metric": "",
    "lr":0.0001,
    "bs_train": 1,
    "bs_valid": 1,
    "weight_decay": 0.0,
    "optimizer": "adam",
    "num_workers": 5,
    "log_wandb": "",
    "wandb_project": "medsam",
}

runner = MedSAMTrainer(params).fit()
# Out:
# Setting up the experiment...
# Done setting up.
# Training has started
# ...
# Validating:   0%|          | 0/12 [00:00<?, ?batchs/s]
# Training has finished
